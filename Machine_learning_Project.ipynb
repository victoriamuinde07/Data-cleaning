# %%
# !pip install --upgrade tensorflow

# %%
import tensorflow as tf
import pandas as pd
dftrain = pd.read_csv('https://storage.googleapis.com/tf-datasets/titanic/train.csv')
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain.drop_duplicates()
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 621         0  female  22.0                   0      0  10.5167   Third
# 622         0    male  28.0                   0      0  10.5000  Second
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain.drop(columns = 'deck')
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain['class'].str.strip(...)
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain['fare'].astype(str).str.replace('[^a-ZA-Z0-9]','')
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain['class'].astype(str).str.replace('NaN','')
dftrain['class'].astype(str).str.replace('nan','')
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 2           1  female  26.0                   0      0   7.9250   Third
# 3           1  female  35.0                   1      0  53.1000   First
# 4           0    male  28.0                   0      0   8.4583   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 622         0    male  28.0                   0      0  10.5000  Second
# 623         0    male  25.0                   0      0   7.0500   Third
# 624         1  female  19.0                   0      0  30.0000   First
# 625         0  female  28.0                   1      2  23.4500   Third
# 626         0    male  32.0                   0      0   7.7500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain['alone'].str.replace('y','yes').str.replace('n','no')
# Out:
# 0       no
# 1       no
# 2      yes
# 3       no
# 4      yes
#       ...
# 622    yes
# 623    yes
# 624    yes
# 625     no
# 626    yes
# Name: alone, Length: 627, dtype: object

# %%
for x in dftrain.index:
  if dftrain.loc[x,'alone'] == 'y':
    dftrain.drop(x,inplace=True)
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 3           1  female  35.0                   1      0  53.1000   First
# 5           0    male   2.0                   3      1  21.0750   Third
# 6           1  female  27.0                   0      2  11.1333   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 609         1  female  27.0                   1      0  13.8583  Second
# 611         1    male   4.0                   1      1  11.1333   Third
# 613         1  female  47.0                   1      1  52.5542   First
# 616         1  female  28.0                   1      0  24.0000  Second
# 625         0  female  28.0                   1      2  23.4500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
dftrain.reset_index(drop=True)
dftrain
# Out:
#      survived     sex   age  n_siblings_spouses  parch     fare   class  \
# 0           0    male  22.0                   1      0   7.2500   Third
# 1           1  female  38.0                   1      0  71.2833   First
# 3           1  female  35.0                   1      0  53.1000   First
# 5           0    male   2.0                   3      1  21.0750   Third
# 6           1  female  27.0                   0      2  11.1333   Third
# ..        ...     ...   ...                 ...    ...      ...     ...
# 609         1  female  27.0                   1      0  13.8583  Second
# 611         1    male   4.0                   1      1  11.1333   Third
# 613         1  female  47.0                   1      1  52.5542   First
# 616         1  female  28.0                   1      0  24.0000  Second
# 625         0  female  28.0                   1      2  23.4500   Third
#
#         deck  embark_town alone
# 0    unknown  Southampton     n
# 1          C    Cherbourg     n
# ...

# %%
y = dftrain.survived
y.describe()
# Out:
# count    255.000000
# mean       0.505882
# std        0.500949
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000
# Name: survived, dtype: float64

# %%
dftrain.columns
# Out:
# Index(['survived', 'sex', 'age', 'n_siblings_spouses', 'parch', 'fare',
#        'class', 'deck', 'embark_town', 'alone'],
#       dtype='object')

# %%
train_features=['age','parch']
x = dftrain[train_features]
x.describe()
# Out:
#               age       parch
# count  255.000000  255.000000
# mean    27.885608    0.933333
# std     14.436359    1.015367
# min      0.750000    0.000000
# 25%     18.000000    0.000000
# 50%     28.000000    1.000000
# 75%     36.000000    2.000000
# max     70.000000    5.000000

# %%
dftrain.columns
# Out:
# Index(['survived', 'sex', 'age', 'n_siblings_spouses', 'parch', 'fare',
#        'class', 'deck', 'embark_town', 'alone'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(dftrain['n_siblings_spouses'],dftrain['survived'])

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state=1)
model.fit(x,y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
print("making predictions of the data:")
print(model.predict(x.head()))
# Out:
# making predictions of the data:
# [0.         1.         1.         0.33333333 0.5       ]

# %%
from sklearn.metrics import mean_absolute_error
pred = model.predict(x)
print(type(mean_absolute_percentage_error))
mea = mean_absolute_percentage_error(y,pred)
print(mea)
# Out:
# <class 'function'>
# 494270320880221.44
